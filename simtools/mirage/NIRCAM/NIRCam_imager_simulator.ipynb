# %% [markdown]
# # NIRCam imager simulator

# %%
import os
# For examining outputs
from glob import glob
from scipy.stats import sigmaclip
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# %matplotlib inline
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
os.environ["MIRAGE_DATA"] = "/Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/"
os.environ["CRDS_DATA"] = "/Users/spacegrey/crds_cache"
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds.stsci.edu"

# %%
# mirage imports
import yaml
from mirage import imaging_simulator
from mirage.seed_image import catalog_seed_image
from mirage.dark import dark_prep
from mirage.ramp_generator import obs_generator
from mirage.yaml import yaml_generator

from mirage.catalogs.catalog_generator import ExtendedCatalog
from mirage.catalogs.create_catalog import combine_catalogs
from mirage.imaging_simulator import ImgSim
from mirage.reference_files.downloader import download_file
#from mirage.seed_image.fits_seed_image import ImgSeed
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %% [markdown]
# ## Calculate the conversion factor from Jy to ADU/s
# Included:
# - Telescope aperture (D)
# - Filter width (dlam)
# - Sensor gain in e-/ADU (gain)
# - Quantum efficiency (QE)
#
# Not included:
# - Filter transmissivity
# - Atmospheric extinction

# %%
from astropy import units as u
from astropy import constants as const
D = 6.5 * u.m
QE = 0.9
gain = 2.05
lam_ref = 2 * u.um
dlam = 0.457 * u.um
E_ph = const.h * const.c / lam_ref.to(u.m)
Jy2SI = (1 * u.Jy).to(u.J * u.s**-1 * u.m**-2 * u.um**-1, equivalencies=u.spectral_density(2* u.um))
Jy2DN = (Jy2SI / E_ph) * (D/2)**2 * dlam * QE * (1 / gain)
print("1 Jy at {0:5.2f} corresponds to {1:5.2f}".format(lam_ref, Jy2DN))
# Out:
# 1 Jy at  2.00 um corresponds to 15991365.34 1 / s

# %% [markdown]
# ## Simulation configs

# %%
# Specify the xmnl and pointing files exported from APT
xml_file = './image2_data/image2_shallow4.xml'
pointing_file = './image2_data/image2_shallow4.pointing'

# Source catalogs to be used.
cat_dict = {'extended':'image2_data/source_catalog_file.cat'}

# Set reference file values. 
# Setting to 'crds_full_name' will search for and download needed calibration reference files (commonly referred to as CRDS reference files) when the yaml_generator is run. 
# Setting to 'crds' will put placeholders in the yaml files and save the downloading for when the simulated images are created.
reffile_defaults = 'crds'

# Optionally set the cosmic ray library and rate
cosmic_rays = {'library': 'SUNMAX', 'scale': 1.0}

# Optionally set the background signal rates to be used
background = 'medium'

# Optionally set the telescope roll angle (PAV3) for the observations
pav3 = 0

# Optionally set the observation date to use for the data. Note that this information
# is placed in the headers of the output files, but not used by Mirage in any way.
dates = '2022-10-31'

ghosts = False
convolve_ghosts = False

# Set the directory into which the yaml files and simulation output will be written
yaml_dir = './image2_data/'
simulation_dir = './image2_sim/'

# specify the data reduction state of the Mirage outputs
datatype = 'linear'

# %% [markdown]
# ## Generate yaml input file

# %%
# For simu for the 1st time, run the yaml generator 
yam = yaml_generator.SimInput(input_xml=xml_file, pointing_file=pointing_file,
                              catalogs=cat_dict, cosmic_rays=cosmic_rays,
                              background=background, roll_angle=pav3,
                              dates=dates, reffile_defaults=reffile_defaults,
                              add_ghosts=ghosts, convolve_ghosts_with_psf=convolve_ghosts,
                              verbose=True, output_dir=yaml_dir,
                              simdata_output_dir=simulation_dir,
                              datatype=datatype)
yam.create_inputs()

yfiles = glob(os.path.join(yaml_dir,'jw*.yaml'))
# Out:
# 2021-05-31 18:04:33,156 - mirage.yaml.yaml_generator - INFO - Running yaml_generator....
#
# 2021-05-31 18:04:33,156 - stpipe - INFO - Running yaml_generator....
#
# 2021-05-31 18:04:33,156 - stpipe - INFO - Running yaml_generator....
#
# 2021-05-31 18:04:33,163 - mirage.yaml.yaml_generator - INFO - using APT xml file: ./image2_data/image2_shallow4.xml
#
# 2021-05-31 18:04:33,163 - stpipe - INFO - using APT xml file: ./image2_data/image2_shallow4.xml
#
# 2021-05-31 18:04:33,163 - stpipe - INFO - using APT xml file: ./image2_data/image2_shallow4.xml
#
# 2021-05-31 18:04:33,167 - mirage.yaml.yaml_generator - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 18:04:33,167 - stpipe - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 18:04:33,167 - stpipe - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 18:04:33,208 - mirage.apt.read_apt_xml - INFO - Running read_apt_xml....
#
# 2021-05-31 18:04:33,208 - stpipe - INFO - Running read_apt_xml....
#
# 2021-05-31 18:04:33,208 - stpipe - INFO - Running read_apt_xml....
#
# 2021-05-31 18:04:33,224 - mirage.apt.read_apt_xml - INFO - target_info:
# 2021-05-31 18:04:33,224 - stpipe - INFO - target_info:
# 2021-05-31 18:04:33,224 - stpipe - INFO - target_info:
# 2021-05-31 18:04:33,228 - mirage.apt.read_apt_xml - INFO - {'IMAGE-2': ('03:10:4.8000', '-10:05:24.00')}
# 2021-05-31 18:04:33,228 - stpipe - INFO - {'IMAGE-2': ('03:10:4.8000', '-10:05:24.00')}
# 2021-05-31 18:04:33,228 - stpipe - INFO - {'IMAGE-2': ('03:10:4.8000', '-10:05:24.00')}
# 2021-05-31 18:04:33,234 - mirage.apt.read_apt_xml - INFO - ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 2021-05-31 18:04:33,234 - stpipe - INFO - ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 2021-05-31 18:04:33,234 - stpipe - INFO - ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 2021-05-31 18:04:33,238 - mirage.apt.read_apt_xml - INFO - Observation `001` labelled `Simple Imaging Example` uses template `NircamImaging`
# 2021-05-31 18:04:33,238 - stpipe - INFO - Observation `001` labelled `Simple Imaging Example` uses template `NircamImaging`
# 2021-05-31 18:04:33,238 - stpipe - INFO - Observation `001` labelled `Simple Imaging Example` uses template `NircamImaging`
# 2021-05-31 18:04:33,243 - mirage.apt.read_apt_xml - INFO - APTObservationParams Dictionary holds 0 entries before reading template
# 2021-05-31 18:04:33,243 - stpipe - INFO - APTObservationParams Dictionary holds 0 entries before reading template
# 2021-05-31 18:04:33,243 - stpipe - INFO - APTObservationParams Dictionary holds 0 entries before reading template
# 2021-05-31 18:04:33,250 - mirage.apt.read_apt_xml - INFO - Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# 2021-05-31 18:04:33,250 - stpipe - INFO - Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# 2021-05-31 18:04:33,250 - stpipe - INFO - Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# 2021-05-31 18:04:33,254 - mirage.apt.read_apt_xml - INFO - Number of dithers: 1 primary * 1 subpixel = 1
# 2021-05-31 18:04:33,254 - stpipe - INFO - Number of dithers: 1 primary * 1 subpixel = 1
# 2021-05-31 18:04:33,254 - stpipe - INFO - Number of dithers: 1 primary * 1 subpixel = 1
# 2021-05-31 18:04:33,258 - mirage.apt.read_apt_xml - INFO - Dictionary read from template has 1 entries.
# 2021-05-31 18:04:33,258 - stpipe - INFO - Dictionary read from template has 1 entries.
# 2021-05-31 18:04:33,258 - stpipe - INFO - Dictionary read from template has 1 entries.
# 2021-05-31 18:04:33,266 - mirage.apt.read_apt_xml - INFO - Found 1 tile(s) for observation 001 Simple Imaging Example
# 2021-05-31 18:04:33,266 - stpipe - INFO - Found 1 tile(s) for observation 001 Simple Imaging Example
# 2021-05-31 18:04:33,266 - stpipe - INFO - Found 1 tile(s) for observation 001 Simple Imaging Example
# 2021-05-31 18:04:33,269 - mirage.apt.read_apt_xml - INFO - Found 1 visits with numbers: [1]
# 2021-05-31 18:04:33,269 - stpipe - INFO - Found 1 visits with numbers: [1]
# 2021-05-31 18:04:33,269 - stpipe - INFO - Found 1 visits with numbers: [1]
# 2021-05-31 18:04:33,273 - mirage.apt.read_apt_xml - INFO - APTObservationParams Dictionary holds 1 entries after reading template (+1 entries)
# 2021-05-31 18:04:33,273 - stpipe - INFO - APTObservationParams Dictionary holds 1 entries after reading template (+1 entries)
# 2021-05-31 18:04:33,273 - stpipe - INFO - APTObservationParams Dictionary holds 1 entries after reading template (+1 entries)
# 2021-05-31 18:04:33,276 - mirage.apt.read_apt_xml - INFO - Finished reading APT xml file.
# 2021-05-31 18:04:33,276 - stpipe - INFO - Finished reading APT xml file.
# 2021-05-31 18:04:33,276 - stpipe - INFO - Finished reading APT xml file.
# 2021-05-31 18:04:33,279 - mirage.apt.read_apt_xml - INFO - ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 2021-05-31 18:04:33,279 - stpipe - INFO - ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 2021-05-31 18:04:33,279 - stpipe - INFO - ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 2021-05-31 18:04:33,299 - mirage.yaml.generate_observationlist.expand_for_dithers - INFO - Number of entries before expanding dithers: 1
# 2021-05-31 18:04:33,299 - stpipe - INFO - Number of entries before expanding dithers: 1
# 2021-05-31 18:04:33,299 - stpipe - INFO - Number of entries before expanding dithers: 1
# 2021-05-31 18:04:33,303 - mirage.yaml.generate_observationlist.expand_for_dithers - INFO - Number of entries after expanding dithers:  1
# 2021-05-31 18:04:33,303 - stpipe - INFO - Number of entries after expanding dithers:  1
# 2021-05-31 18:04:33,303 - stpipe - INFO - Number of entries after expanding dithers:  1
# 2021-05-31 18:04:33,307 - mirage.yaml.generate_observationlist.expand_for_dithers - INFO - Expanded table for Observation 001 has 1 entries
# 2021-05-31 18:04:33,307 - stpipe - INFO - Expanded table for Observation 001 has 1 entries
# 2021-05-31 18:04:33,307 - stpipe - INFO - Expanded table for Observation 001 has 1 entries
# 2021-05-31 18:04:33,315 - mirage.yaml.generate_observationlist.get_observation_dict - INFO - Wrote 1 observations and 1 entries to /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_data/observation_list.yaml
# 2021-05-31 18:04:33,315 - stpipe - INFO - Wrote 1 observations and 1 entries to /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_data/observation_list.yaml
# 2021-05-31 18:04:33,315 - stpipe - INFO - Wrote 1 observations and 1 entries to /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_data/observation_list.yaml
# 2021-05-31 18:04:36,577 - mirage.apt.apt_inputs - INFO - csv exposure list written to /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_data/Observation_table_for_image2_shallow4.csv
# 2021-05-31 18:04:36,577 - stpipe - INFO - csv exposure list written to /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_data/Observation_table_for_image2_shallow4.csv
# 2021-05-31 18:04:36,577 - stpipe - INFO - csv exposure list written to /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_data/Observation_table_for_image2_shallow4.csv
# 2021-05-31 18:04:37,033 - mirage.yaml.yaml_generator - INFO - No PSF path provided. Using default path as PSF path for all yamls.
# 2021-05-31 18:04:37,033 - stpipe - INFO - No PSF path provided. Using default path as PSF path for all yamls.
# 2021-05-31 18:04:37,033 - stpipe - INFO - No PSF path provided. Using default path as PSF path for all yamls.
# 2021-05-31 18:04:37,073 - mirage.yaml.yaml_generator - INFO - Updated observation table file saved to /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_data/Observation_table_for_image2_shallow4.xml_with_yaml_parameters.csv
# 2021-05-31 18:04:37,073 - stpipe - INFO - Updated observation table file saved to /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_data/Observation_table_for_image2_shallow4.xml_with_yaml_parameters.csv
# 2021-05-31 18:04:37,073 - stpipe - INFO - Updated observation table file saved to /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_data/Observation_table_for_image2_shallow4.xml_with_yaml_parameters.csv
# 2021-05-31 18:04:37,086 - mirage.yaml.yaml_generator - INFO -
#
# 2021-05-31 18:04:37,086 - stpipe - INFO -
#
# 2021-05-31 18:04:37,086 - stpipe - INFO -
#
# 2021-05-31 18:04:37,088 - mirage.yaml.yaml_generator - INFO - Observation 001:
# 2021-05-31 18:04:37,088 - stpipe - INFO - Observation 001:
# 2021-05-31 18:04:37,088 - stpipe - INFO - Observation 001:
# 2021-05-31 18:04:37,090 - mirage.yaml.yaml_generator - INFO -     Prime: NIRCAM
# 2021-05-31 18:04:37,090 - stpipe - INFO -     Prime: NIRCAM
# 2021-05-31 18:04:37,090 - stpipe - INFO -     Prime: NIRCAM
# 2021-05-31 18:04:37,092 - mirage.yaml.yaml_generator - INFO -     1 visit(s)
# 2021-05-31 18:04:37,092 - stpipe - INFO -     1 visit(s)
# 2021-05-31 18:04:37,092 - stpipe - INFO -     1 visit(s)
# 2021-05-31 18:04:37,095 - mirage.yaml.yaml_generator - INFO -     1 activity(ies)
# 2021-05-31 18:04:37,095 - stpipe - INFO -     1 activity(ies)
# 2021-05-31 18:04:37,095 - stpipe - INFO -     1 activity(ies)
# 2021-05-31 18:04:37,098 - mirage.yaml.yaml_generator - INFO -     10 NIRCam detector(s) in module A and B
# 2021-05-31 18:04:37,098 - stpipe - INFO -     10 NIRCam detector(s) in module A and B
# 2021-05-31 18:04:37,098 - stpipe - INFO -     10 NIRCam detector(s) in module A and B
# 2021-05-31 18:04:37,100 - mirage.yaml.yaml_generator - INFO -     10 file(s)
# 2021-05-31 18:04:37,100 - stpipe - INFO -     10 file(s)
# 2021-05-31 18:04:37,100 - stpipe - INFO -     10 file(s)
# 2021-05-31 18:04:37,103 - mirage.yaml.yaml_generator - INFO - 10 output files written to: /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_data
# 2021-05-31 18:04:37,103 - stpipe - INFO - 10 output files written to: /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_data
# 2021-05-31 18:04:37,103 - stpipe - INFO - 10 output files written to: /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_data
# 2021-05-31 18:04:37,107 - mirage.yaml.yaml_generator - INFO - Yaml generator complete
# 2021-05-31 18:04:37,107 - stpipe - INFO - Yaml generator complete
# 2021-05-31 18:04:37,107 - stpipe - INFO - Yaml generator complete

# %% [markdown]
# ## Run the simulation

# %%
# Run all steps of the imaging simulator for yaml file #1
yfile = './image2_data/jw00005001001_01101_00001_nrca1.yaml'

img_sim = imaging_simulator.ImgSim()
img_sim.paramfile = yfile
img_sim.create()
# Out:
# 2021-05-31 18:04:38,711 - mirage.imaging_simulator - INFO -
#
# Running imaging_simulator....
#
# 2021-05-31 18:04:38,711 - stpipe - INFO -
#
# Running imaging_simulator....
#
# 2021-05-31 18:04:38,711 - stpipe - INFO -
#
# Running imaging_simulator....
#
# 2021-05-31 18:04:38,717 - mirage.imaging_simulator - INFO - using parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
# 2021-05-31 18:04:38,717 - stpipe - INFO - using parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
# 2021-05-31 18:04:38,717 - stpipe - INFO - using parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
# 2021-05-31 18:04:38,755 - mirage.seed_image.catalog_seed_image - INFO -
#
# Running catalog_seed_image..
#
# 2021-05-31 18:04:38,755 - stpipe - INFO -
#
# Running catalog_seed_image..
#
# 2021-05-31 18:04:38,755 - stpipe - INFO -
#
# Running catalog_seed_image..
#
# 2021-05-31 18:04:38,759 - mirage.seed_image.catalog_seed_image - INFO - Reading parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
#
# 2021-05-31 18:04:38,759 - stpipe - INFO - Reading parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
#
# 2021-05-31 18:04:38,759 - stpipe - INFO - Reading parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
#
# 2021-05-31 18:04:38,769 - mirage.seed_image.catalog_seed_image - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 18:04:38,769 - stpipe - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 18:04:38,769 - stpipe - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 18:04:38,789 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_mask_0033.fits as the badpixmask reference file.
# 2021-05-31 18:04:38,789 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_mask_0033.fits as the badpixmask reference file.
# 2021-05-31 18:04:38,789 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_mask_0033.fits as the badpixmask reference file.
# 2021-05-31 18:04:38,796 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0026.fits as the superbias reference file.
# 2021-05-31 18:04:38,796 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0026.fits as the superbias reference file.
# 2021-05-31 18:04:38,796 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0026.fits as the superbias reference file.
# 2021-05-31 18:04:38,805 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0056.fits as the linearity reference file.
# 2021-05-31 18:04:38,805 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0056.fits as the linearity reference file.
# 2021-05-31 18:04:38,805 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0056.fits as the linearity reference file.
# 2021-05-31 18:04:38,809 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0064.fits as the saturation reference file.
# 2021-05-31 18:04:38,809 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0064.fits as the saturation reference file.
# 2021-05-31 18:04:38,809 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0064.fits as the saturation reference file.
# 2021-05-31 18:04:38,816 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_gain_0050.fits as the gain reference file.
# 2021-05-31 18:04:38,816 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_gain_0050.fits as the gain reference file.
# 2021-05-31 18:04:38,816 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_gain_0050.fits as the gain reference file.
# 2021-05-31 18:04:38,823 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_flat_0337.fits as the pixelflat reference file.
# 2021-05-31 18:04:38,823 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_flat_0337.fits as the pixelflat reference file.
# 2021-05-31 18:04:38,823 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_flat_0337.fits as the pixelflat reference file.
# 2021-05-31 18:04:38,828 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0026.fits as the ipc reference file.
# 2021-05-31 18:04:38,828 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0026.fits as the ipc reference file.
# 2021-05-31 18:04:38,828 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0026.fits as the ipc reference file.
# 2021-05-31 18:04:38,835 - mirage.utils.utils.full_paths - INFO - Found an existing inverted kernel for this IPC file: /Users/spacegrey/crds_cache/references/jwst/nircam/Kernel_to_add_IPC_effects_from_jwst_nircam_ipc_0026.fits
# 2021-05-31 18:04:38,835 - stpipe - INFO - Found an existing inverted kernel for this IPC file: /Users/spacegrey/crds_cache/references/jwst/nircam/Kernel_to_add_IPC_effects_from_jwst_nircam_ipc_0026.fits
# 2021-05-31 18:04:38,835 - stpipe - INFO - Found an existing inverted kernel for this IPC file: /Users/spacegrey/crds_cache/references/jwst/nircam/Kernel_to_add_IPC_effects_from_jwst_nircam_ipc_0026.fits
# 2021-05-31 18:04:38,845 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0093.asdf as the astrometric reference file.
# 2021-05-31 18:04:38,845 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0093.asdf as the astrometric reference file.
# 2021-05-31 18:04:38,845 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0093.asdf as the astrometric reference file.
# 2021-05-31 18:04:38,854 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_area_0017.fits as the pixelAreaMap reference file.
# 2021-05-31 18:04:38,854 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_area_0017.fits as the pixelAreaMap reference file.
# 2021-05-31 18:04:38,854 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_area_0017.fits as the pixelAreaMap reference file.
# 2021-05-31 18:04:38,861 - mirage.reference_files.utils.get_transmission_file - INFO - POM Transmission filename: None
# 2021-05-31 18:04:38,861 - stpipe - INFO - POM Transmission filename: None
# 2021-05-31 18:04:38,861 - stpipe - INFO - POM Transmission filename: None
# 2021-05-31 18:04:38,865 - mirage.utils.utils.full_paths - INFO - From grism library, found None as the POM transmission file.
# 2021-05-31 18:04:38,865 - stpipe - INFO - From grism library, found None as the POM transmission file.
# 2021-05-31 18:04:38,865 - stpipe - INFO - From grism library, found None as the POM transmission file.
# 2021-05-31 18:04:38,871 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_photom_0074.fits as the photom reference file.
# 2021-05-31 18:04:38,871 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_photom_0074.fits as the photom reference file.
# 2021-05-31 18:04:38,871 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_photom_0074.fits as the photom reference file.
# 2021-05-31 18:04:38,885 - mirage.seed_image.catalog_seed_image - INFO - Requested readout pattern SHALLOW4 is valid. Using the nframe = 4 and nskip = 1
# 2021-05-31 18:04:38,885 - stpipe - INFO - Requested readout pattern SHALLOW4 is valid. Using the nframe = 4 and nskip = 1
# 2021-05-31 18:04:38,885 - stpipe - INFO - Requested readout pattern SHALLOW4 is valid. Using the nframe = 4 and nskip = 1
# 2021-05-31 18:04:38,890 - mirage.seed_image.catalog_seed_image - INFO - No point source catalog provided in yaml file.
# 2021-05-31 18:04:38,890 - stpipe - INFO - No point source catalog provided in yaml file.
# 2021-05-31 18:04:38,890 - stpipe - INFO - No point source catalog provided in yaml file.
# 2021-05-31 18:04:38,894 - mirage.seed_image.catalog_seed_image - INFO - No galaxy catalog provided in yaml file.
# 2021-05-31 18:04:38,894 - stpipe - INFO - No galaxy catalog provided in yaml file.
# 2021-05-31 18:04:38,894 - stpipe - INFO - No galaxy catalog provided in yaml file.
# 2021-05-31 18:04:39,258 - mirage.seed_image.catalog_seed_image - INFO - SIAF: Requested NRCA1_FULL   got NRCA1_FULL
# 2021-05-31 18:04:39,258 - stpipe - INFO - SIAF: Requested NRCA1_FULL   got NRCA1_FULL
# 2021-05-31 18:04:39,258 - stpipe - INFO - SIAF: Requested NRCA1_FULL   got NRCA1_FULL
# 2021-05-31 18:04:39,260 - mirage.seed_image.catalog_seed_image - INFO - Calculating background rate using jwst_background based on medium level
# 2021-05-31 18:04:39,260 - stpipe - INFO - Calculating background rate using jwst_background based on medium level
# 2021-05-31 18:04:39,260 - stpipe - INFO - Calculating background rate using jwst_background based on medium level
# 2021-05-31 18:04:39,262 - mirage.seed_image.catalog_seed_image - INFO - Using /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/config/F200W_CLEAR_nircam_plus_ote_throughput_moda_sorted.txt filter throughput file for background calculation.
# 2021-05-31 18:04:39,262 - stpipe - INFO - Using /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/config/F200W_CLEAR_nircam_plus_ote_throughput_moda_sorted.txt filter throughput file for background calculation.
# 2021-05-31 18:04:39,262 - stpipe - INFO - Using /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/config/F200W_CLEAR_nircam_plus_ote_throughput_moda_sorted.txt filter throughput file for background calculation.
# 2021-05-31 18:04:40,690 - mirage.seed_image.catalog_seed_image - INFO - Background rate determined using medium level: 0.08639046219689375
# 2021-05-31 18:04:40,690 - stpipe - INFO - Background rate determined using medium level: 0.08639046219689375
# 2021-05-31 18:04:40,690 - stpipe - INFO - Background rate determined using medium level: 0.08639046219689375
# 2021-05-31 18:04:40,820 - mirage.seed_image.catalog_seed_image - INFO - No transmission file given. Assuming full transmission for all pixels, not including flat field effects. (no e.g. occulters blocking any pixels).
# 2021-05-31 18:04:40,820 - stpipe - INFO - No transmission file given. Assuming full transmission for all pixels, not including flat field effects. (no e.g. occulters blocking any pixels).
# 2021-05-31 18:04:40,820 - stpipe - INFO - No transmission file given. Assuming full transmission for all pixels, not including flat field effects. (no e.g. occulters blocking any pixels).
# 2021-05-31 18:04:40,845 - mirage.seed_image.catalog_seed_image - INFO - XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2021-05-31 18:04:40,845 - stpipe - INFO - XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2021-05-31 18:04:40,845 - stpipe - INFO - XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2021-05-31 18:04:40,847 - mirage.seed_image.catalog_seed_image - INFO - Seed image output dimensions (x, y) are: (2048, 2048)
# 2021-05-31 18:04:40,847 - stpipe - INFO - Seed image output dimensions (x, y) are: (2048, 2048)
# 2021-05-31 18:04:40,847 - stpipe - INFO - Seed image output dimensions (x, y) are: (2048, 2048)
# 2021-05-31 18:04:40,850 - mirage.seed_image.catalog_seed_image - INFO - XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2021-05-31 18:04:40,850 - stpipe - INFO - XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2021-05-31 18:04:40,850 - stpipe - INFO - XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2021-05-31 18:04:40,852 - mirage.seed_image.catalog_seed_image - INFO - Frametime is 10.736770000000002
# 2021-05-31 18:04:40,852 - stpipe - INFO - Frametime is 10.736770000000002
# 2021-05-31 18:04:40,852 - stpipe - INFO - Frametime is 10.736770000000002
# 2021-05-31 18:04:40,874 - mirage.psf.psf_selection.get_gridded_psf_library - INFO - PSFs will be generated using: /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/gridded_psf_library/nircam_nrca1_f200w_clear_fovp69_samp5_npsf9_predicted_realization0.fits
# 2021-05-31 18:04:40,874 - stpipe - INFO - PSFs will be generated using: /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/gridded_psf_library/nircam_nrca1_f200w_clear_fovp69_samp5_npsf9_predicted_realization0.fits
# 2021-05-31 18:04:40,874 - stpipe - INFO - PSFs will be generated using: /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/gridded_psf_library/nircam_nrca1_f200w_clear_fovp69_samp5_npsf9_predicted_realization0.fits
# 2021-05-31 18:04:40,983 - mirage.psf.psf_selection.get_psf_wings - INFO - PSF wings will be from: nircam_nrca1_f200w_clear_fovp401_samp1_predicted_realization0.fits
# 2021-05-31 18:04:40,983 - stpipe - INFO - PSF wings will be from: nircam_nrca1_f200w_clear_fovp401_samp1_predicted_realization0.fits
# 2021-05-31 18:04:40,983 - stpipe - INFO - PSF wings will be from: nircam_nrca1_f200w_clear_fovp401_samp1_predicted_realization0.fits
# 2021-05-31 18:04:40,999 - mirage.seed_image.catalog_seed_image - INFO - Creating signal rate image of sidereal synthetic inputs.
# 2021-05-31 18:04:40,999 - stpipe - INFO - Creating signal rate image of sidereal synthetic inputs.
# 2021-05-31 18:04:40,999 - stpipe - INFO - Creating signal rate image of sidereal synthetic inputs.
# 2021-05-31 18:04:41,005 - mirage.seed_image.catalog_seed_image - INFO - Extended list input positions assumed to be in units of RA and Dec.
# 2021-05-31 18:04:41,005 - stpipe - INFO - Extended list input positions assumed to be in units of RA and Dec.
# 2021-05-31 18:04:41,005 - stpipe - INFO - Extended list input positions assumed to be in units of RA and Dec.
# 2021-05-31 18:04:41,023 - mirage.seed_image.catalog_seed_image - WARNING - WARNING: Catalog source_catalog_file.cat does not have a magnitude column called nircam_f200w_magnitude, but does have a generic 'magnitude' column. Continuing simulation using that.
# 2021-05-31 18:04:41,023 - stpipe - WARNING - WARNING: Catalog source_catalog_file.cat does not have a magnitude column called nircam_f200w_magnitude, but does have a generic 'magnitude' column. Continuing simulation using that.
# 2021-05-31 18:04:41,023 - stpipe - WARNING - WARNING: Catalog source_catalog_file.cat does not have a magnitude column called nircam_f200w_magnitude, but does have a generic 'magnitude' column. Continuing simulation using that.
# 2021-05-31 18:04:41,044 - mirage.seed_image.catalog_seed_image - WARNING - No magnitude given for extended source in image2_50au_npix840_nscat1e7ADU.fits.
# 2021-05-31 18:04:41,044 - stpipe - WARNING - No magnitude given for extended source in image2_50au_npix840_nscat1e7ADU.fits.
# 2021-05-31 18:04:41,044 - stpipe - WARNING - No magnitude given for extended source in image2_50au_npix840_nscat1e7ADU.fits.
# 2021-05-31 18:04:41,046 - mirage.seed_image.catalog_seed_image - WARNING - Assuming the original file is in units of counts per sec.
# 2021-05-31 18:04:41,046 - stpipe - WARNING - Assuming the original file is in units of counts per sec.
# 2021-05-31 18:04:41,046 - stpipe - WARNING - Assuming the original file is in units of counts per sec.
# 2021-05-31 18:04:41,050 - mirage.seed_image.catalog_seed_image - WARNING - Multiplying original file values by 'extendedscale'.
# 2021-05-31 18:04:41,050 - stpipe - WARNING - Multiplying original file values by 'extendedscale'.
# 2021-05-31 18:04:41,050 - stpipe - WARNING - Multiplying original file values by 'extendedscale'.
# 2021-05-31 18:04:41,054 - mirage.seed_image.catalog_seed_image - INFO - Number of extended sources found within or close to the requested aperture: 1
# 2021-05-31 18:04:41,054 - stpipe - INFO - Number of extended sources found within or close to the requested aperture: 1
# 2021-05-31 18:04:41,054 - stpipe - INFO - Number of extended sources found within or close to the requested aperture: 1
# 2021-05-31 18:04:41,153 - mirage.seed_image.catalog_seed_image - INFO - Number of extended sources present within the aperture: 1
# 2021-05-31 18:04:41,153 - stpipe - INFO - Number of extended sources present within the aperture: 1
# 2021-05-31 18:04:41,153 - stpipe - INFO - Number of extended sources present within the aperture: 1
# 2021-05-31 18:04:41,156 - mirage.seed_image.catalog_seed_image - INFO - Seed image is 2D.
# 2021-05-31 18:04:41,156 - stpipe - INFO - Seed image is 2D.
# 2021-05-31 18:04:41,156 - stpipe - INFO - Seed image is 2D.
# 2021-05-31 18:04:41,440 - mirage.seed_image.catalog_seed_image - INFO - Extended object image and segmap saved as /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_F200W_CLEAR_extended_seed_image.fits
# 2021-05-31 18:04:41,440 - stpipe - INFO - Extended object image and segmap saved as /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_F200W_CLEAR_extended_seed_image.fits
# 2021-05-31 18:04:41,440 - stpipe - INFO - Extended object image and segmap saved as /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_F200W_CLEAR_extended_seed_image.fits
# 2021-05-31 18:04:41,624 - mirage.seed_image.catalog_seed_image - INFO - Multiplying seed by POM transmission image.
# 2021-05-31 18:04:41,624 - stpipe - INFO - Multiplying seed by POM transmission image.
# 2021-05-31 18:04:41,624 - stpipe - INFO - Multiplying seed by POM transmission image.
# 2021-05-31 18:04:41,634 - mirage.seed_image.catalog_seed_image - INFO - Seed image is 2D.
# 2021-05-31 18:04:41,634 - stpipe - INFO - Seed image is 2D.
# 2021-05-31 18:04:41,634 - stpipe - INFO - Seed image is 2D.
# 2021-05-31 18:04:41,868 - mirage.seed_image.catalog_seed_image - INFO - Final seed image and segmentation map saved as /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_F200W_CLEAR_final_seed_image.fits
# 2021-05-31 18:04:41,868 - stpipe - INFO - Final seed image and segmentation map saved as /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_F200W_CLEAR_final_seed_image.fits
# 2021-05-31 18:04:41,868 - stpipe - INFO - Final seed image and segmentation map saved as /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_F200W_CLEAR_final_seed_image.fits
# 2021-05-31 18:04:41,870 - mirage.seed_image.catalog_seed_image - INFO - Seed image, segmentation map, and metadata available as:
# 2021-05-31 18:04:41,870 - stpipe - INFO - Seed image, segmentation map, and metadata available as:
# 2021-05-31 18:04:41,870 - stpipe - INFO - Seed image, segmentation map, and metadata available as:
# 2021-05-31 18:04:41,873 - mirage.seed_image.catalog_seed_image - INFO - self.seedimage, self.seed_segmap, self.seedinfo.
#
#
# 2021-05-31 18:04:41,873 - stpipe - INFO - self.seedimage, self.seed_segmap, self.seedinfo.
#
#
# 2021-05-31 18:04:41,873 - stpipe - INFO - self.seedimage, self.seed_segmap, self.seedinfo.
#
#
# 2021-05-31 18:04:41,875 - mirage.imaging_simulator - INFO - Perform dark preparation:
# 2021-05-31 18:04:41,875 - stpipe - INFO - Perform dark preparation:
# 2021-05-31 18:04:41,875 - stpipe - INFO - Perform dark preparation:
# 2021-05-31 18:04:41,910 - mirage.dark.dark_prep - INFO -
#
# Running dark_prep..
#
# 2021-05-31 18:04:41,910 - stpipe - INFO -
#
# Running dark_prep..
#
# 2021-05-31 18:04:41,910 - stpipe - INFO -
#
# Running dark_prep..
#
# 2021-05-31 18:04:41,914 - mirage.dark.dark_prep - INFO - Reading parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
#
# 2021-05-31 18:04:41,914 - stpipe - INFO - Reading parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
#
# 2021-05-31 18:04:41,914 - stpipe - INFO - Reading parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
#
# 2021-05-31 18:04:41,924 - mirage.dark.dark_prep - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 18:04:41,924 - stpipe - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 18:04:41,924 - stpipe - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 18:04:41,928 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_mask_0033.fits as the badpixmask reference file.
# 2021-05-31 18:04:41,928 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_mask_0033.fits as the badpixmask reference file.
# 2021-05-31 18:04:41,928 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_mask_0033.fits as the badpixmask reference file.
# 2021-05-31 18:04:41,934 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0026.fits as the superbias reference file.
# 2021-05-31 18:04:41,934 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0026.fits as the superbias reference file.
# 2021-05-31 18:04:41,934 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0026.fits as the superbias reference file.
# 2021-05-31 18:04:41,940 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0056.fits as the linearity reference file.
# 2021-05-31 18:04:41,940 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0056.fits as the linearity reference file.
# 2021-05-31 18:04:41,940 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0056.fits as the linearity reference file.
# 2021-05-31 18:04:41,950 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0064.fits as the saturation reference file.
# 2021-05-31 18:04:41,950 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0064.fits as the saturation reference file.
# 2021-05-31 18:04:41,950 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0064.fits as the saturation reference file.
# 2021-05-31 18:04:41,954 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_gain_0050.fits as the gain reference file.
# 2021-05-31 18:04:41,954 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_gain_0050.fits as the gain reference file.
# 2021-05-31 18:04:41,954 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_gain_0050.fits as the gain reference file.
# 2021-05-31 18:04:41,957 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_flat_0337.fits as the pixelflat reference file.
# 2021-05-31 18:04:41,957 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_flat_0337.fits as the pixelflat reference file.
# 2021-05-31 18:04:41,957 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_flat_0337.fits as the pixelflat reference file.
# 2021-05-31 18:04:41,961 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0026.fits as the ipc reference file.
# 2021-05-31 18:04:41,961 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0026.fits as the ipc reference file.
# 2021-05-31 18:04:41,961 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0026.fits as the ipc reference file.
# 2021-05-31 18:04:41,965 - mirage.utils.utils.full_paths - INFO - Found an existing inverted kernel for this IPC file: /Users/spacegrey/crds_cache/references/jwst/nircam/Kernel_to_add_IPC_effects_from_jwst_nircam_ipc_0026.fits
# 2021-05-31 18:04:41,965 - stpipe - INFO - Found an existing inverted kernel for this IPC file: /Users/spacegrey/crds_cache/references/jwst/nircam/Kernel_to_add_IPC_effects_from_jwst_nircam_ipc_0026.fits
# 2021-05-31 18:04:41,965 - stpipe - INFO - Found an existing inverted kernel for this IPC file: /Users/spacegrey/crds_cache/references/jwst/nircam/Kernel_to_add_IPC_effects_from_jwst_nircam_ipc_0026.fits
# 2021-05-31 18:04:41,971 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0093.asdf as the astrometric reference file.
# 2021-05-31 18:04:41,971 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0093.asdf as the astrometric reference file.
# 2021-05-31 18:04:41,971 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0093.asdf as the astrometric reference file.
# 2021-05-31 18:04:41,976 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_area_0017.fits as the pixelAreaMap reference file.
# 2021-05-31 18:04:41,976 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_area_0017.fits as the pixelAreaMap reference file.
# 2021-05-31 18:04:41,976 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_area_0017.fits as the pixelAreaMap reference file.
# 2021-05-31 18:04:41,982 - mirage.reference_files.utils.get_transmission_file - INFO - POM Transmission filename: None
# 2021-05-31 18:04:41,982 - stpipe - INFO - POM Transmission filename: None
# 2021-05-31 18:04:41,982 - stpipe - INFO - POM Transmission filename: None
# 2021-05-31 18:04:41,988 - mirage.utils.utils.full_paths - INFO - From grism library, found None as the POM transmission file.
# 2021-05-31 18:04:41,988 - stpipe - INFO - From grism library, found None as the POM transmission file.
# 2021-05-31 18:04:41,988 - stpipe - INFO - From grism library, found None as the POM transmission file.
# 2021-05-31 18:04:41,990 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_photom_0074.fits as the photom reference file.
# 2021-05-31 18:04:41,990 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_photom_0074.fits as the photom reference file.
# 2021-05-31 18:04:41,990 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_photom_0074.fits as the photom reference file.
# 2021-05-31 18:04:41,995 - mirage.dark.dark_prep - INFO - Requested readout pattern SHALLOW4 is valid. Using the nframe = 4 and nskip = 1
# 2021-05-31 18:04:41,995 - stpipe - INFO - Requested readout pattern SHALLOW4 is valid. Using the nframe = 4 and nskip = 1
# 2021-05-31 18:04:41,995 - stpipe - INFO - Requested readout pattern SHALLOW4 is valid. Using the nframe = 4 and nskip = 1
# 2021-05-31 18:04:42,341 - mirage.dark.dark_prep - INFO - Segment number: 0
# 2021-05-31 18:04:42,341 - stpipe - INFO - Segment number: 0
# 2021-05-31 18:04:42,341 - stpipe - INFO - Segment number: 0
# 2021-05-31 18:04:42,344 - mirage.dark.dark_prep - INFO - Number of integrations: 1
# 2021-05-31 18:04:42,344 - stpipe - INFO - Number of integrations: 1
# 2021-05-31 18:04:42,344 - stpipe - INFO - Number of integrations: 1
# 2021-05-31 18:04:42,346 - mirage.dark.dark_prep - INFO - Dark files to use:
# 2021-05-31 18:04:42,346 - stpipe - INFO - Dark files to use:
# 2021-05-31 18:04:42,346 - stpipe - INFO - Dark files to use:
# 2021-05-31 18:04:42,348 - mirage.dark.dark_prep - INFO - /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/darks/linearized/A1/Linearized_Dark_and_SBRefpix_NRCNRCA1-DARK-60082202011_1_481_SE_2016-01-09T00h03m58_uncal.fits
# 2021-05-31 18:04:42,348 - stpipe - INFO - /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/darks/linearized/A1/Linearized_Dark_and_SBRefpix_NRCNRCA1-DARK-60082202011_1_481_SE_2016-01-09T00h03m58_uncal.fits
# 2021-05-31 18:04:42,348 - stpipe - INFO - /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/darks/linearized/A1/Linearized_Dark_and_SBRefpix_NRCNRCA1-DARK-60082202011_1_481_SE_2016-01-09T00h03m58_uncal.fits
# 2021-05-31 18:04:42,350 - mirage.dark.dark_prep - INFO - Working on dark file: /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/darks/linearized/A1/Linearized_Dark_and_SBRefpix_NRCNRCA1-DARK-60082202011_1_481_SE_2016-01-09T00h03m58_uncal.fits
# 2021-05-31 18:04:42,350 - stpipe - INFO - Working on dark file: /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/darks/linearized/A1/Linearized_Dark_and_SBRefpix_NRCNRCA1-DARK-60082202011_1_481_SE_2016-01-09T00h03m58_uncal.fits
# 2021-05-31 18:04:42,350 - stpipe - INFO - Working on dark file: /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/darks/linearized/A1/Linearized_Dark_and_SBRefpix_NRCNRCA1-DARK-60082202011_1_481_SE_2016-01-09T00h03m58_uncal.fits
# 2021-05-31 18:04:42,351 - mirage.dark.dark_prep - INFO - Reading in linearized dark current ramp from /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/darks/linearized/A1/Linearized_Dark_and_SBRefpix_NRCNRCA1-DARK-60082202011_1_481_SE_2016-01-09T00h03m58_uncal.fits
# 2021-05-31 18:04:42,351 - stpipe - INFO - Reading in linearized dark current ramp from /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/darks/linearized/A1/Linearized_Dark_and_SBRefpix_NRCNRCA1-DARK-60082202011_1_481_SE_2016-01-09T00h03m58_uncal.fits
# 2021-05-31 18:04:42,351 - stpipe - INFO - Reading in linearized dark current ramp from /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/darks/linearized/A1/Linearized_Dark_and_SBRefpix_NRCNRCA1-DARK-60082202011_1_481_SE_2016-01-09T00h03m58_uncal.fits
# 2021-05-31 18:04:42,442 - mirage.dark.dark_prep - INFO - Averaging dark current ramp. Frames [0 1 2 3], to become group 0
# 2021-05-31 18:04:42,442 - stpipe - INFO - Averaging dark current ramp. Frames [0 1 2 3], to become group 0
# 2021-05-31 18:04:42,442 - stpipe - INFO - Averaging dark current ramp. Frames [0 1 2 3], to become group 0
# 2021-05-31 18:04:43,186 - mirage.dark.dark_prep - INFO - Averaging dark current ramp. Frames [5 6 7 8], to become group 1
# 2021-05-31 18:04:43,186 - stpipe - INFO - Averaging dark current ramp. Frames [5 6 7 8], to become group 1
# 2021-05-31 18:04:43,186 - stpipe - INFO - Averaging dark current ramp. Frames [5 6 7 8], to become group 1
# 2021-05-31 18:04:43,915 - mirage.dark.dark_prep - INFO - Averaging dark current ramp. Frames [10 11 12 13], to become group 2
# 2021-05-31 18:04:43,915 - stpipe - INFO - Averaging dark current ramp. Frames [10 11 12 13], to become group 2
# 2021-05-31 18:04:43,915 - stpipe - INFO - Averaging dark current ramp. Frames [10 11 12 13], to become group 2
# 2021-05-31 18:04:44,591 - mirage.dark.dark_prep - INFO - Averaging dark current ramp. Frames [15 16 17 18], to become group 3
# 2021-05-31 18:04:44,591 - stpipe - INFO - Averaging dark current ramp. Frames [15 16 17 18], to become group 3
# 2021-05-31 18:04:44,591 - stpipe - INFO - Averaging dark current ramp. Frames [15 16 17 18], to become group 3
# 2021-05-31 18:04:45,314 - mirage.dark.dark_prep - INFO - Averaging dark current ramp. Frames [20 21 22 23], to become group 4
# 2021-05-31 18:04:45,314 - stpipe - INFO - Averaging dark current ramp. Frames [20 21 22 23], to become group 4
# 2021-05-31 18:04:45,314 - stpipe - INFO - Averaging dark current ramp. Frames [20 21 22 23], to become group 4
# 2021-05-31 18:04:46,049 - mirage.dark.dark_prep - INFO - Averaging dark current ramp. Frames [25 26 27 28], to become group 5
# 2021-05-31 18:04:46,049 - stpipe - INFO - Averaging dark current ramp. Frames [25 26 27 28], to become group 5
# 2021-05-31 18:04:46,049 - stpipe - INFO - Averaging dark current ramp. Frames [25 26 27 28], to become group 5
# 2021-05-31 18:04:46,701 - mirage.dark.dark_prep - INFO - Averaging dark current ramp. Frames [30 31 32 33], to become group 6
# 2021-05-31 18:04:46,701 - stpipe - INFO - Averaging dark current ramp. Frames [30 31 32 33], to become group 6
# 2021-05-31 18:04:46,701 - stpipe - INFO - Averaging dark current ramp. Frames [30 31 32 33], to become group 6
# 2021-05-31 18:04:47,322 - mirage.dark.dark_prep - INFO - Averaging dark current ramp. Frames [35 36 37 38], to become group 7
# 2021-05-31 18:04:47,322 - stpipe - INFO - Averaging dark current ramp. Frames [35 36 37 38], to become group 7
# 2021-05-31 18:04:47,322 - stpipe - INFO - Averaging dark current ramp. Frames [35 36 37 38], to become group 7
# 2021-05-31 18:04:47,973 - mirage.dark.dark_prep - INFO - Averaging dark current ramp. Frames [40 41 42 43], to become group 8
# 2021-05-31 18:04:47,973 - stpipe - INFO - Averaging dark current ramp. Frames [40 41 42 43], to become group 8
# 2021-05-31 18:04:47,973 - stpipe - INFO - Averaging dark current ramp. Frames [40 41 42 43], to become group 8
# 2021-05-31 18:04:48,761 - mirage.dark.dark_prep - INFO - Averaging dark current ramp. Frames [45 46 47 48], to become group 9
# 2021-05-31 18:04:48,761 - stpipe - INFO - Averaging dark current ramp. Frames [45 46 47 48], to become group 9
# 2021-05-31 18:04:48,761 - stpipe - INFO - Averaging dark current ramp. Frames [45 46 47 48], to become group 9
# 2021-05-31 18:04:49,570 - mirage.dark.dark_prep - INFO - DARK has been reordered to (1, 10, 2048, 2048) to match the input readpattern of SHALLOW4
# 2021-05-31 18:04:49,570 - stpipe - INFO - DARK has been reordered to (1, 10, 2048, 2048) to match the input readpattern of SHALLOW4
# 2021-05-31 18:04:49,570 - stpipe - INFO - DARK has been reordered to (1, 10, 2048, 2048) to match the input readpattern of SHALLOW4
# 2021-05-31 18:04:49,576 - mirage.dark.dark_prep - INFO - Setting integration 0 to use file Linearized_Dark_and_SBRefpix_NRCNRCA1-DARK-60082202011_1_481_SE_2016-01-09T00h03m58_uncal.fits
#
# 2021-05-31 18:04:49,576 - stpipe - INFO - Setting integration 0 to use file Linearized_Dark_and_SBRefpix_NRCNRCA1-DARK-60082202011_1_481_SE_2016-01-09T00h03m58_uncal.fits
#
# 2021-05-31 18:04:49,576 - stpipe - INFO - Setting integration 0 to use file Linearized_Dark_and_SBRefpix_NRCNRCA1-DARK-60082202011_1_481_SE_2016-01-09T00h03m58_uncal.fits
#
# 2021-05-31 18:04:51,636 - mirage.dark.dark_prep - INFO - Linearized dark frame plus superbias and referencepixel signals, as well as zeroframe, saved to /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_linear_dark_prep_object.fits. This can be used as input to the observation generator.
# 2021-05-31 18:04:51,636 - stpipe - INFO - Linearized dark frame plus superbias and referencepixel signals, as well as zeroframe, saved to /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_linear_dark_prep_object.fits. This can be used as input to the observation generator.
# 2021-05-31 18:04:51,636 - stpipe - INFO - Linearized dark frame plus superbias and referencepixel signals, as well as zeroframe, saved to /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_linear_dark_prep_object.fits. This can be used as input to the observation generator.
# 2021-05-31 18:04:51,638 - mirage.dark.dark_prep - INFO -
#
# Segment 1 out of 1 complete.
# 2021-05-31 18:04:51,638 - stpipe - INFO -
#
# Segment 1 out of 1 complete.
# 2021-05-31 18:04:51,638 - stpipe - INFO -
#
# Segment 1 out of 1 complete.
# 2021-05-31 18:04:51,675 - mirage.ramp_generator.obs_generator - INFO -
#
# Running observation generator....
#
# 2021-05-31 18:04:51,675 - stpipe - INFO -
#
# Running observation generator....
#
# 2021-05-31 18:04:51,675 - stpipe - INFO -
#
# Running observation generator....
#
# 2021-05-31 18:04:51,679 - mirage.ramp_generator.obs_generator - INFO - Reading parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
#
# 2021-05-31 18:04:51,679 - stpipe - INFO - Reading parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
#
# 2021-05-31 18:04:51,679 - stpipe - INFO - Reading parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
#
# 2021-05-31 18:04:51,683 - mirage.ramp_generator.obs_generator - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 18:04:51,683 - stpipe - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 18:04:51,683 - stpipe - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 18:04:51,691 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_mask_0033.fits as the badpixmask reference file.
# 2021-05-31 18:04:51,691 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_mask_0033.fits as the badpixmask reference file.
# 2021-05-31 18:04:51,691 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_mask_0033.fits as the badpixmask reference file.
# 2021-05-31 18:04:51,694 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0026.fits as the superbias reference file.
# 2021-05-31 18:04:51,694 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0026.fits as the superbias reference file.
# 2021-05-31 18:04:51,694 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0026.fits as the superbias reference file.
# 2021-05-31 18:04:51,699 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0056.fits as the linearity reference file.
# 2021-05-31 18:04:51,699 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0056.fits as the linearity reference file.
# 2021-05-31 18:04:51,699 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0056.fits as the linearity reference file.
# 2021-05-31 18:04:51,703 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0064.fits as the saturation reference file.
# 2021-05-31 18:04:51,703 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0064.fits as the saturation reference file.
# 2021-05-31 18:04:51,703 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0064.fits as the saturation reference file.
# 2021-05-31 18:04:51,706 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_gain_0050.fits as the gain reference file.
# 2021-05-31 18:04:51,706 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_gain_0050.fits as the gain reference file.
# 2021-05-31 18:04:51,706 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_gain_0050.fits as the gain reference file.
# 2021-05-31 18:04:51,711 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_flat_0337.fits as the pixelflat reference file.
# 2021-05-31 18:04:51,711 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_flat_0337.fits as the pixelflat reference file.
# 2021-05-31 18:04:51,711 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_flat_0337.fits as the pixelflat reference file.
# 2021-05-31 18:04:51,717 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0026.fits as the ipc reference file.
# 2021-05-31 18:04:51,717 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0026.fits as the ipc reference file.
# 2021-05-31 18:04:51,717 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0026.fits as the ipc reference file.
# 2021-05-31 18:04:51,720 - mirage.utils.utils.full_paths - INFO - Found an existing inverted kernel for this IPC file: /Users/spacegrey/crds_cache/references/jwst/nircam/Kernel_to_add_IPC_effects_from_jwst_nircam_ipc_0026.fits
# 2021-05-31 18:04:51,720 - stpipe - INFO - Found an existing inverted kernel for this IPC file: /Users/spacegrey/crds_cache/references/jwst/nircam/Kernel_to_add_IPC_effects_from_jwst_nircam_ipc_0026.fits
# 2021-05-31 18:04:51,720 - stpipe - INFO - Found an existing inverted kernel for this IPC file: /Users/spacegrey/crds_cache/references/jwst/nircam/Kernel_to_add_IPC_effects_from_jwst_nircam_ipc_0026.fits
# 2021-05-31 18:04:51,723 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0093.asdf as the astrometric reference file.
# 2021-05-31 18:04:51,723 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0093.asdf as the astrometric reference file.
# 2021-05-31 18:04:51,723 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0093.asdf as the astrometric reference file.
# 2021-05-31 18:04:51,728 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_area_0017.fits as the pixelAreaMap reference file.
# 2021-05-31 18:04:51,728 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_area_0017.fits as the pixelAreaMap reference file.
# 2021-05-31 18:04:51,728 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_area_0017.fits as the pixelAreaMap reference file.
# 2021-05-31 18:04:51,730 - mirage.reference_files.utils.get_transmission_file - INFO - POM Transmission filename: None
# 2021-05-31 18:04:51,730 - stpipe - INFO - POM Transmission filename: None
# 2021-05-31 18:04:51,730 - stpipe - INFO - POM Transmission filename: None
# 2021-05-31 18:04:51,734 - mirage.utils.utils.full_paths - INFO - From grism library, found None as the POM transmission file.
# 2021-05-31 18:04:51,734 - stpipe - INFO - From grism library, found None as the POM transmission file.
# 2021-05-31 18:04:51,734 - stpipe - INFO - From grism library, found None as the POM transmission file.
# 2021-05-31 18:04:51,736 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_photom_0074.fits as the photom reference file.
# 2021-05-31 18:04:51,736 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_photom_0074.fits as the photom reference file.
# 2021-05-31 18:04:51,736 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_photom_0074.fits as the photom reference file.
# 2021-05-31 18:04:51,739 - mirage.ramp_generator.obs_generator - INFO - Reading in dark file: /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_linear_dark_prep_object.fits
# 2021-05-31 18:04:51,739 - stpipe - INFO - Reading in dark file: /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_linear_dark_prep_object.fits
# 2021-05-31 18:04:51,739 - stpipe - INFO - Reading in dark file: /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_linear_dark_prep_object.fits
# 2021-05-31 18:04:51,837 - mirage.ramp_generator.obs_generator - INFO - Requested readout pattern SHALLOW4 is valid. Using nframe = 4 and nskip = 1
# 2021-05-31 18:04:51,837 - stpipe - INFO - Requested readout pattern SHALLOW4 is valid. Using nframe = 4 and nskip = 1
# 2021-05-31 18:04:51,837 - stpipe - INFO - Requested readout pattern SHALLOW4 is valid. Using nframe = 4 and nskip = 1
# 2021-05-31 18:04:52,423 - mirage.ramp_generator.obs_generator - INFO - Frametime is 10.736770000000002
# 2021-05-31 18:04:52,423 - stpipe - INFO - Frametime is 10.736770000000002
# 2021-05-31 18:04:52,423 - stpipe - INFO - Frametime is 10.736770000000002
# 2021-05-31 18:04:52,433 - mirage.ramp_generator.obs_generator - INFO - Base cosmic ray probability per pixel per second: 5.762e-06
# 2021-05-31 18:04:52,433 - stpipe - INFO - Base cosmic ray probability per pixel per second: 5.762e-06
# 2021-05-31 18:04:52,433 - stpipe - INFO - Base cosmic ray probability per pixel per second: 5.762e-06
# 2021-05-31 18:04:52,556 - mirage.ramp_generator.obs_generator - INFO - The linearity coefficients of 7874 pixels are NaNs. Setting these coefficients such that no linearity correction is made.
# 2021-05-31 18:04:52,556 - stpipe - INFO - The linearity coefficients of 7874 pixels are NaNs. Setting these coefficients such that no linearity correction is made.
# 2021-05-31 18:04:52,556 - stpipe - INFO - The linearity coefficients of 7874 pixels are NaNs. Setting these coefficients such that no linearity correction is made.
# 2021-05-31 18:04:53,013 - mirage.ramp_generator.obs_generator - INFO - Integration 0:
# 2021-05-31 18:04:53,013 - stpipe - INFO - Integration 0:
# 2021-05-31 18:04:53,013 - stpipe - INFO - Integration 0:
# 2021-05-31 18:04:53,515 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 0 into group 0
# 2021-05-31 18:04:53,515 - stpipe - INFO -     Averaging frame 0 into group 0
# 2021-05-31 18:04:53,515 - stpipe - INFO -     Averaging frame 0 into group 0
# 2021-05-31 18:04:54,034 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 1 into group 0
# 2021-05-31 18:04:54,034 - stpipe - INFO -     Averaging frame 1 into group 0
# 2021-05-31 18:04:54,034 - stpipe - INFO -     Averaging frame 1 into group 0
# 2021-05-31 18:04:54,497 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 2 into group 0
# 2021-05-31 18:04:54,497 - stpipe - INFO -     Averaging frame 2 into group 0
# 2021-05-31 18:04:54,497 - stpipe - INFO -     Averaging frame 2 into group 0
# 2021-05-31 18:04:54,890 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 3 into group 0
# 2021-05-31 18:04:54,890 - stpipe - INFO -     Averaging frame 3 into group 0
# 2021-05-31 18:04:54,890 - stpipe - INFO -     Averaging frame 3 into group 0
# 2021-05-31 18:04:55,300 - mirage.ramp_generator.obs_generator - INFO -     Skipping frame 4
# 2021-05-31 18:04:55,300 - stpipe - INFO -     Skipping frame 4
# 2021-05-31 18:04:55,300 - stpipe - INFO -     Skipping frame 4
# 2021-05-31 18:04:55,661 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 5 into group 1
# 2021-05-31 18:04:55,661 - stpipe - INFO -     Averaging frame 5 into group 1
# 2021-05-31 18:04:55,661 - stpipe - INFO -     Averaging frame 5 into group 1
# 2021-05-31 18:04:56,042 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 6 into group 1
# 2021-05-31 18:04:56,042 - stpipe - INFO -     Averaging frame 6 into group 1
# 2021-05-31 18:04:56,042 - stpipe - INFO -     Averaging frame 6 into group 1
# 2021-05-31 18:04:56,402 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 7 into group 1
# 2021-05-31 18:04:56,402 - stpipe - INFO -     Averaging frame 7 into group 1
# 2021-05-31 18:04:56,402 - stpipe - INFO -     Averaging frame 7 into group 1
# 2021-05-31 18:04:56,759 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 8 into group 1
# 2021-05-31 18:04:56,759 - stpipe - INFO -     Averaging frame 8 into group 1
# 2021-05-31 18:04:56,759 - stpipe - INFO -     Averaging frame 8 into group 1
# 2021-05-31 18:04:57,150 - mirage.ramp_generator.obs_generator - INFO -     Skipping frame 9
# 2021-05-31 18:04:57,150 - stpipe - INFO -     Skipping frame 9
# 2021-05-31 18:04:57,150 - stpipe - INFO -     Skipping frame 9
# 2021-05-31 18:04:57,503 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 10 into group 2
# 2021-05-31 18:04:57,503 - stpipe - INFO -     Averaging frame 10 into group 2
# 2021-05-31 18:04:57,503 - stpipe - INFO -     Averaging frame 10 into group 2
# 2021-05-31 18:04:57,856 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 11 into group 2
# 2021-05-31 18:04:57,856 - stpipe - INFO -     Averaging frame 11 into group 2
# 2021-05-31 18:04:57,856 - stpipe - INFO -     Averaging frame 11 into group 2
# 2021-05-31 18:04:58,208 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 12 into group 2
# 2021-05-31 18:04:58,208 - stpipe - INFO -     Averaging frame 12 into group 2
# 2021-05-31 18:04:58,208 - stpipe - INFO -     Averaging frame 12 into group 2
# 2021-05-31 18:04:58,559 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 13 into group 2
# 2021-05-31 18:04:58,559 - stpipe - INFO -     Averaging frame 13 into group 2
# 2021-05-31 18:04:58,559 - stpipe - INFO -     Averaging frame 13 into group 2
# 2021-05-31 18:04:58,941 - mirage.ramp_generator.obs_generator - INFO -     Skipping frame 14
# 2021-05-31 18:04:58,941 - stpipe - INFO -     Skipping frame 14
# 2021-05-31 18:04:58,941 - stpipe - INFO -     Skipping frame 14
# 2021-05-31 18:04:59,295 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 15 into group 3
# 2021-05-31 18:04:59,295 - stpipe - INFO -     Averaging frame 15 into group 3
# 2021-05-31 18:04:59,295 - stpipe - INFO -     Averaging frame 15 into group 3
# 2021-05-31 18:04:59,643 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 16 into group 3
# 2021-05-31 18:04:59,643 - stpipe - INFO -     Averaging frame 16 into group 3
# 2021-05-31 18:04:59,643 - stpipe - INFO -     Averaging frame 16 into group 3
# 2021-05-31 18:04:59,992 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 17 into group 3
# 2021-05-31 18:04:59,992 - stpipe - INFO -     Averaging frame 17 into group 3
# 2021-05-31 18:04:59,992 - stpipe - INFO -     Averaging frame 17 into group 3
# 2021-05-31 18:05:00,343 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 18 into group 3
# 2021-05-31 18:05:00,343 - stpipe - INFO -     Averaging frame 18 into group 3
# 2021-05-31 18:05:00,343 - stpipe - INFO -     Averaging frame 18 into group 3
# 2021-05-31 18:05:00,727 - mirage.ramp_generator.obs_generator - INFO -     Skipping frame 19
# 2021-05-31 18:05:00,727 - stpipe - INFO -     Skipping frame 19
# 2021-05-31 18:05:00,727 - stpipe - INFO -     Skipping frame 19
# 2021-05-31 18:05:01,071 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 20 into group 4
# 2021-05-31 18:05:01,071 - stpipe - INFO -     Averaging frame 20 into group 4
# 2021-05-31 18:05:01,071 - stpipe - INFO -     Averaging frame 20 into group 4
# 2021-05-31 18:05:01,421 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 21 into group 4
# 2021-05-31 18:05:01,421 - stpipe - INFO -     Averaging frame 21 into group 4
# 2021-05-31 18:05:01,421 - stpipe - INFO -     Averaging frame 21 into group 4
# 2021-05-31 18:05:01,771 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 22 into group 4
# 2021-05-31 18:05:01,771 - stpipe - INFO -     Averaging frame 22 into group 4
# 2021-05-31 18:05:01,771 - stpipe - INFO -     Averaging frame 22 into group 4
# 2021-05-31 18:05:02,123 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 23 into group 4
# 2021-05-31 18:05:02,123 - stpipe - INFO -     Averaging frame 23 into group 4
# 2021-05-31 18:05:02,123 - stpipe - INFO -     Averaging frame 23 into group 4
# 2021-05-31 18:05:02,499 - mirage.ramp_generator.obs_generator - INFO -     Skipping frame 24
# 2021-05-31 18:05:02,499 - stpipe - INFO -     Skipping frame 24
# 2021-05-31 18:05:02,499 - stpipe - INFO -     Skipping frame 24
# 2021-05-31 18:05:02,844 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 25 into group 5
# 2021-05-31 18:05:02,844 - stpipe - INFO -     Averaging frame 25 into group 5
# 2021-05-31 18:05:02,844 - stpipe - INFO -     Averaging frame 25 into group 5
# 2021-05-31 18:05:03,190 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 26 into group 5
# 2021-05-31 18:05:03,190 - stpipe - INFO -     Averaging frame 26 into group 5
# 2021-05-31 18:05:03,190 - stpipe - INFO -     Averaging frame 26 into group 5
# 2021-05-31 18:05:03,539 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 27 into group 5
# 2021-05-31 18:05:03,539 - stpipe - INFO -     Averaging frame 27 into group 5
# 2021-05-31 18:05:03,539 - stpipe - INFO -     Averaging frame 27 into group 5
# 2021-05-31 18:05:03,889 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 28 into group 5
# 2021-05-31 18:05:03,889 - stpipe - INFO -     Averaging frame 28 into group 5
# 2021-05-31 18:05:03,889 - stpipe - INFO -     Averaging frame 28 into group 5
# 2021-05-31 18:05:04,268 - mirage.ramp_generator.obs_generator - INFO -     Skipping frame 29
# 2021-05-31 18:05:04,268 - stpipe - INFO -     Skipping frame 29
# 2021-05-31 18:05:04,268 - stpipe - INFO -     Skipping frame 29
# 2021-05-31 18:05:04,620 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 30 into group 6
# 2021-05-31 18:05:04,620 - stpipe - INFO -     Averaging frame 30 into group 6
# 2021-05-31 18:05:04,620 - stpipe - INFO -     Averaging frame 30 into group 6
# 2021-05-31 18:05:04,967 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 31 into group 6
# 2021-05-31 18:05:04,967 - stpipe - INFO -     Averaging frame 31 into group 6
# 2021-05-31 18:05:04,967 - stpipe - INFO -     Averaging frame 31 into group 6
# 2021-05-31 18:05:05,313 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 32 into group 6
# 2021-05-31 18:05:05,313 - stpipe - INFO -     Averaging frame 32 into group 6
# 2021-05-31 18:05:05,313 - stpipe - INFO -     Averaging frame 32 into group 6
# 2021-05-31 18:05:05,662 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 33 into group 6
# 2021-05-31 18:05:05,662 - stpipe - INFO -     Averaging frame 33 into group 6
# 2021-05-31 18:05:05,662 - stpipe - INFO -     Averaging frame 33 into group 6
# 2021-05-31 18:05:06,042 - mirage.ramp_generator.obs_generator - INFO -     Skipping frame 34
# 2021-05-31 18:05:06,042 - stpipe - INFO -     Skipping frame 34
# 2021-05-31 18:05:06,042 - stpipe - INFO -     Skipping frame 34
# 2021-05-31 18:05:06,385 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 35 into group 7
# 2021-05-31 18:05:06,385 - stpipe - INFO -     Averaging frame 35 into group 7
# 2021-05-31 18:05:06,385 - stpipe - INFO -     Averaging frame 35 into group 7
# 2021-05-31 18:05:06,734 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 36 into group 7
# 2021-05-31 18:05:06,734 - stpipe - INFO -     Averaging frame 36 into group 7
# 2021-05-31 18:05:06,734 - stpipe - INFO -     Averaging frame 36 into group 7
# 2021-05-31 18:05:07,092 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 37 into group 7
# 2021-05-31 18:05:07,092 - stpipe - INFO -     Averaging frame 37 into group 7
# 2021-05-31 18:05:07,092 - stpipe - INFO -     Averaging frame 37 into group 7
# 2021-05-31 18:05:07,443 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 38 into group 7
# 2021-05-31 18:05:07,443 - stpipe - INFO -     Averaging frame 38 into group 7
# 2021-05-31 18:05:07,443 - stpipe - INFO -     Averaging frame 38 into group 7
# 2021-05-31 18:05:07,819 - mirage.ramp_generator.obs_generator - INFO -     Skipping frame 39
# 2021-05-31 18:05:07,819 - stpipe - INFO -     Skipping frame 39
# 2021-05-31 18:05:07,819 - stpipe - INFO -     Skipping frame 39
# 2021-05-31 18:05:08,163 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 40 into group 8
# 2021-05-31 18:05:08,163 - stpipe - INFO -     Averaging frame 40 into group 8
# 2021-05-31 18:05:08,163 - stpipe - INFO -     Averaging frame 40 into group 8
# 2021-05-31 18:05:08,510 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 41 into group 8
# 2021-05-31 18:05:08,510 - stpipe - INFO -     Averaging frame 41 into group 8
# 2021-05-31 18:05:08,510 - stpipe - INFO -     Averaging frame 41 into group 8
# 2021-05-31 18:05:08,859 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 42 into group 8
# 2021-05-31 18:05:08,859 - stpipe - INFO -     Averaging frame 42 into group 8
# 2021-05-31 18:05:08,859 - stpipe - INFO -     Averaging frame 42 into group 8
# 2021-05-31 18:05:09,204 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 43 into group 8
# 2021-05-31 18:05:09,204 - stpipe - INFO -     Averaging frame 43 into group 8
# 2021-05-31 18:05:09,204 - stpipe - INFO -     Averaging frame 43 into group 8
# 2021-05-31 18:05:09,586 - mirage.ramp_generator.obs_generator - INFO -     Skipping frame 44
# 2021-05-31 18:05:09,586 - stpipe - INFO -     Skipping frame 44
# 2021-05-31 18:05:09,586 - stpipe - INFO -     Skipping frame 44
# 2021-05-31 18:05:09,923 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 45 into group 9
# 2021-05-31 18:05:09,923 - stpipe - INFO -     Averaging frame 45 into group 9
# 2021-05-31 18:05:09,923 - stpipe - INFO -     Averaging frame 45 into group 9
# 2021-05-31 18:05:10,261 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 46 into group 9
# 2021-05-31 18:05:10,261 - stpipe - INFO -     Averaging frame 46 into group 9
# 2021-05-31 18:05:10,261 - stpipe - INFO -     Averaging frame 46 into group 9
# 2021-05-31 18:05:10,597 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 47 into group 9
# 2021-05-31 18:05:10,597 - stpipe - INFO -     Averaging frame 47 into group 9
# 2021-05-31 18:05:10,597 - stpipe - INFO -     Averaging frame 47 into group 9
# 2021-05-31 18:05:10,935 - mirage.ramp_generator.obs_generator - INFO -     Averaging frame 48 into group 9
# 2021-05-31 18:05:10,935 - stpipe - INFO -     Averaging frame 48 into group 9
# 2021-05-31 18:05:10,935 - stpipe - INFO -     Averaging frame 48 into group 9
# 2021-05-31 18:05:15,066 - mirage.ramp_generator.obs_generator - INFO - Adding crosstalk
# 2021-05-31 18:05:15,066 - stpipe - INFO - Adding crosstalk
# 2021-05-31 18:05:15,066 - stpipe - INFO - Adding crosstalk
# 2021-05-31 18:05:19,359 - mirage.ramp_generator.obs_generator - INFO - Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-05-31 18:05:19,359 - stpipe - INFO - Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-05-31 18:05:19,359 - stpipe - INFO - Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-05-31 18:05:19,482 - mirage.ramp_generator.obs_generator - INFO - Keyword WEIRD does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-05-31 18:05:19,482 - stpipe - INFO - Keyword WEIRD does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-05-31 18:05:19,482 - stpipe - INFO - Keyword WEIRD does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-05-31 18:05:19,899 - mirage.ramp_generator.obs_generator - INFO -
#
# Populating xref_sci in output file:
# 2021-05-31 18:05:19,899 - stpipe - INFO -
#
# Populating xref_sci in output file:
# 2021-05-31 18:05:19,899 - stpipe - INFO -
#
# Populating xref_sci in output file:
# 2021-05-31 18:05:19,901 - mirage.ramp_generator.obs_generator - INFO - 1024.5
# 2021-05-31 18:05:19,901 - stpipe - INFO - 1024.5
# 2021-05-31 18:05:19,901 - stpipe - INFO - 1024.5
# 2021-05-31 18:05:21,259 - mirage.ramp_generator.obs_generator - INFO - Final linearized exposure saved to:
# 2021-05-31 18:05:21,259 - stpipe - INFO - Final linearized exposure saved to:
# 2021-05-31 18:05:21,259 - stpipe - INFO - Final linearized exposure saved to:
# 2021-05-31 18:05:21,261 - mirage.ramp_generator.obs_generator - INFO - /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_linear.fits
# 2021-05-31 18:05:21,261 - stpipe - INFO - /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_linear.fits
# 2021-05-31 18:05:21,261 - stpipe - INFO - /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_linear.fits
# 2021-05-31 18:05:21,264 - mirage.ramp_generator.obs_generator - INFO -
#
# Segment 1 out of 1 complete.
# 2021-05-31 18:05:21,264 - stpipe - INFO -
#
# Segment 1 out of 1 complete.
# 2021-05-31 18:05:21,264 - stpipe - INFO -
#
# Segment 1 out of 1 complete.
# 2021-05-31 18:05:21,266 - mirage.ramp_generator.obs_generator - INFO - Observation generation complete.
# 2021-05-31 18:05:21,266 - stpipe - INFO - Observation generation complete.
# 2021-05-31 18:05:21,266 - stpipe - INFO - Observation generation complete.
# 2021-05-31 18:05:21,369 - mirage.imaging_simulator - INFO -
# Imaging simulator complete
# 2021-05-31 18:05:21,369 - stpipe - INFO -
# Imaging simulator complete
# 2021-05-31 18:05:21,369 - stpipe - INFO -
# Imaging simulator complete

# %% [markdown]
# ## Plot results

# %%
# Plot seed image
plt.figure(figsize=(7,5))
extent = (xmin, xmax, ymin, ymax) = (993, 1077, 935, 1019)
#extent = (xmin, xmax, ymin, ymax) = (993-50, 1077+50, 935-50, 1019+50)
plt.imshow(img_sim.seedimage[ymin:ymax,xmin:xmax], extent=extent,norm=LogNorm(vmin=1e-1,vmax=1e4), origin="lower")
plt.title('Seed Image')
plt.colorbar().set_label('DN$^{-}$/s')
print(img_sim.seedimage.min(), img_sim.seedimage.max())
# Out:
# 0.0 4105.265682907198

# %%
# Plot final image
lin_file = 'image2_sim/jw00005001001_01101_00001_nrca1_linear.fits'
with fits.open(lin_file) as hdulist:
    linear_data = hdulist['SCI'].data
print(linear_data.shape)
plt.figure(figsize=(7,5))
extent = (xmin, xmax, ymin, ymax) = (993, 1077, 935, 1019)
#extent = (xmin, xmax, ymin, ymax) = (993-50, 1077+50, 935-50, 1019+50)

cmap = plt.cm.viridis
cmap.set_bad(color=cmap(0))
plt.imshow(linear_data[0, 9, ymin:ymax, xmin:xmax], extent=extent,norm=LogNorm(vmin=1e2,vmax=1e7), origin="lower")
plt.title('Final Group, T=526.1s')
plt.colorbar().set_label('DN$^{-}$/s')
#print(linear_data[0,3,:,:].min(), linear_data[0,3,:,:].max())
# Out:
# (1, 10, 2048, 2048)

# %% [markdown]
# # Tests and Debugs

# %%
# test make seed image
from mirage.seed_image import catalog_seed_image
yfile = './image2_data/jw00005001001_01101_00001_nrca1.yaml'
cat = catalog_seed_image.Catalog_seed()
cat.paramfile = yfile
cat.make_seed()
# Out:
# 2021-05-31 17:59:50,952 - mirage.seed_image.catalog_seed_image - INFO -
#
# Running catalog_seed_image..
#
# 2021-05-31 17:59:50,952 - stpipe - INFO -
#
# Running catalog_seed_image..
#
# 2021-05-31 17:59:50,952 - stpipe - INFO -
#
# Running catalog_seed_image..
#
# 2021-05-31 17:59:50,954 - mirage.seed_image.catalog_seed_image - INFO - Reading parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
#
# 2021-05-31 17:59:50,954 - stpipe - INFO - Reading parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
#
# 2021-05-31 17:59:50,954 - stpipe - INFO - Reading parameter file: ./image2_data/jw00005001001_01101_00001_nrca1.yaml
#
# 2021-05-31 17:59:50,957 - mirage.seed_image.catalog_seed_image - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 17:59:50,957 - stpipe - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 17:59:50,957 - stpipe - INFO - Original log file name: ./mirage_latest.log
# 2021-05-31 17:59:50,965 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_mask_0033.fits as the badpixmask reference file.
# 2021-05-31 17:59:50,965 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_mask_0033.fits as the badpixmask reference file.
# 2021-05-31 17:59:50,965 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_mask_0033.fits as the badpixmask reference file.
# 2021-05-31 17:59:50,972 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0026.fits as the superbias reference file.
# 2021-05-31 17:59:50,972 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0026.fits as the superbias reference file.
# 2021-05-31 17:59:50,972 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0026.fits as the superbias reference file.
# 2021-05-31 17:59:50,975 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0056.fits as the linearity reference file.
# 2021-05-31 17:59:50,975 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0056.fits as the linearity reference file.
# 2021-05-31 17:59:50,975 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0056.fits as the linearity reference file.
# 2021-05-31 17:59:50,982 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0064.fits as the saturation reference file.
# 2021-05-31 17:59:50,982 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0064.fits as the saturation reference file.
# 2021-05-31 17:59:50,982 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0064.fits as the saturation reference file.
# 2021-05-31 17:59:50,991 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_gain_0050.fits as the gain reference file.
# 2021-05-31 17:59:50,991 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_gain_0050.fits as the gain reference file.
# 2021-05-31 17:59:50,991 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_gain_0050.fits as the gain reference file.
# 2021-05-31 17:59:50,998 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_flat_0337.fits as the pixelflat reference file.
# 2021-05-31 17:59:50,998 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_flat_0337.fits as the pixelflat reference file.
# 2021-05-31 17:59:50,998 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_flat_0337.fits as the pixelflat reference file.
# 2021-05-31 17:59:51,004 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0026.fits as the ipc reference file.
# 2021-05-31 17:59:51,004 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0026.fits as the ipc reference file.
# 2021-05-31 17:59:51,004 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0026.fits as the ipc reference file.
# 2021-05-31 17:59:51,007 - mirage.utils.utils.full_paths - INFO - Found an existing inverted kernel for this IPC file: /Users/spacegrey/crds_cache/references/jwst/nircam/Kernel_to_add_IPC_effects_from_jwst_nircam_ipc_0026.fits
# 2021-05-31 17:59:51,007 - stpipe - INFO - Found an existing inverted kernel for this IPC file: /Users/spacegrey/crds_cache/references/jwst/nircam/Kernel_to_add_IPC_effects_from_jwst_nircam_ipc_0026.fits
# 2021-05-31 17:59:51,007 - stpipe - INFO - Found an existing inverted kernel for this IPC file: /Users/spacegrey/crds_cache/references/jwst/nircam/Kernel_to_add_IPC_effects_from_jwst_nircam_ipc_0026.fits
# 2021-05-31 17:59:51,012 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0093.asdf as the astrometric reference file.
# 2021-05-31 17:59:51,012 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0093.asdf as the astrometric reference file.
# 2021-05-31 17:59:51,012 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0093.asdf as the astrometric reference file.
# 2021-05-31 17:59:51,017 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_area_0017.fits as the pixelAreaMap reference file.
# 2021-05-31 17:59:51,017 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_area_0017.fits as the pixelAreaMap reference file.
# 2021-05-31 17:59:51,017 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_area_0017.fits as the pixelAreaMap reference file.
# 2021-05-31 17:59:51,022 - mirage.reference_files.utils.get_transmission_file - INFO - POM Transmission filename: None
# 2021-05-31 17:59:51,022 - stpipe - INFO - POM Transmission filename: None
# 2021-05-31 17:59:51,022 - stpipe - INFO - POM Transmission filename: None
# 2021-05-31 17:59:51,027 - mirage.utils.utils.full_paths - INFO - From grism library, found None as the POM transmission file.
# 2021-05-31 17:59:51,027 - stpipe - INFO - From grism library, found None as the POM transmission file.
# 2021-05-31 17:59:51,027 - stpipe - INFO - From grism library, found None as the POM transmission file.
# 2021-05-31 17:59:51,031 - mirage.utils.utils.full_paths - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_photom_0074.fits as the photom reference file.
# 2021-05-31 17:59:51,031 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_photom_0074.fits as the photom reference file.
# 2021-05-31 17:59:51,031 - stpipe - INFO - From CRDS, found /Users/spacegrey/crds_cache/references/jwst/nircam/jwst_nircam_photom_0074.fits as the photom reference file.
# 2021-05-31 17:59:51,044 - mirage.seed_image.catalog_seed_image - INFO - Requested readout pattern SHALLOW4 is valid. Using the nframe = 4 and nskip = 1
# 2021-05-31 17:59:51,044 - stpipe - INFO - Requested readout pattern SHALLOW4 is valid. Using the nframe = 4 and nskip = 1
# 2021-05-31 17:59:51,044 - stpipe - INFO - Requested readout pattern SHALLOW4 is valid. Using the nframe = 4 and nskip = 1
# 2021-05-31 17:59:51,046 - mirage.seed_image.catalog_seed_image - INFO - No point source catalog provided in yaml file.
# 2021-05-31 17:59:51,046 - stpipe - INFO - No point source catalog provided in yaml file.
# 2021-05-31 17:59:51,046 - stpipe - INFO - No point source catalog provided in yaml file.
# 2021-05-31 17:59:51,049 - mirage.seed_image.catalog_seed_image - INFO - No galaxy catalog provided in yaml file.
# 2021-05-31 17:59:51,049 - stpipe - INFO - No galaxy catalog provided in yaml file.
# 2021-05-31 17:59:51,049 - stpipe - INFO - No galaxy catalog provided in yaml file.
# 2021-05-31 17:59:51,380 - mirage.seed_image.catalog_seed_image - INFO - SIAF: Requested NRCA1_FULL   got NRCA1_FULL
# 2021-05-31 17:59:51,380 - stpipe - INFO - SIAF: Requested NRCA1_FULL   got NRCA1_FULL
# 2021-05-31 17:59:51,380 - stpipe - INFO - SIAF: Requested NRCA1_FULL   got NRCA1_FULL
# 2021-05-31 17:59:51,383 - mirage.seed_image.catalog_seed_image - INFO - Calculating background rate using jwst_background based on medium level
# 2021-05-31 17:59:51,383 - stpipe - INFO - Calculating background rate using jwst_background based on medium level
# 2021-05-31 17:59:51,383 - stpipe - INFO - Calculating background rate using jwst_background based on medium level
# 2021-05-31 17:59:51,385 - mirage.seed_image.catalog_seed_image - INFO - Using /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/config/F200W_CLEAR_nircam_plus_ote_throughput_moda_sorted.txt filter throughput file for background calculation.
# 2021-05-31 17:59:51,385 - stpipe - INFO - Using /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/config/F200W_CLEAR_nircam_plus_ote_throughput_moda_sorted.txt filter throughput file for background calculation.
# 2021-05-31 17:59:51,385 - stpipe - INFO - Using /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/config/F200W_CLEAR_nircam_plus_ote_throughput_moda_sorted.txt filter throughput file for background calculation.
# 2021-05-31 17:59:52,827 - mirage.seed_image.catalog_seed_image - INFO - Background rate determined using medium level: 0.08639046219689375
# 2021-05-31 17:59:52,827 - stpipe - INFO - Background rate determined using medium level: 0.08639046219689375
# 2021-05-31 17:59:52,827 - stpipe - INFO - Background rate determined using medium level: 0.08639046219689375
# 2021-05-31 17:59:52,940 - mirage.seed_image.catalog_seed_image - INFO - No transmission file given. Assuming full transmission for all pixels, not including flat field effects. (no e.g. occulters blocking any pixels).
# 2021-05-31 17:59:52,940 - stpipe - INFO - No transmission file given. Assuming full transmission for all pixels, not including flat field effects. (no e.g. occulters blocking any pixels).
# 2021-05-31 17:59:52,940 - stpipe - INFO - No transmission file given. Assuming full transmission for all pixels, not including flat field effects. (no e.g. occulters blocking any pixels).
# 2021-05-31 17:59:52,948 - mirage.seed_image.catalog_seed_image - INFO - XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2021-05-31 17:59:52,948 - stpipe - INFO - XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2021-05-31 17:59:52,948 - stpipe - INFO - XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2021-05-31 17:59:52,951 - mirage.seed_image.catalog_seed_image - INFO - Seed image output dimensions (x, y) are: (2048, 2048)
# 2021-05-31 17:59:52,951 - stpipe - INFO - Seed image output dimensions (x, y) are: (2048, 2048)
# 2021-05-31 17:59:52,951 - stpipe - INFO - Seed image output dimensions (x, y) are: (2048, 2048)
# 2021-05-31 17:59:52,953 - mirage.seed_image.catalog_seed_image - INFO - XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2021-05-31 17:59:52,953 - stpipe - INFO - XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2021-05-31 17:59:52,953 - stpipe - INFO - XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 2021-05-31 17:59:52,957 - mirage.seed_image.catalog_seed_image - INFO - Frametime is 10.736770000000002
# 2021-05-31 17:59:52,957 - stpipe - INFO - Frametime is 10.736770000000002
# 2021-05-31 17:59:52,957 - stpipe - INFO - Frametime is 10.736770000000002
# 2021-05-31 17:59:52,966 - mirage.psf.psf_selection.get_gridded_psf_library - INFO - PSFs will be generated using: /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/gridded_psf_library/nircam_nrca1_f200w_clear_fovp69_samp5_npsf9_predicted_realization0.fits
# 2021-05-31 17:59:52,966 - stpipe - INFO - PSFs will be generated using: /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/gridded_psf_library/nircam_nrca1_f200w_clear_fovp69_samp5_npsf9_predicted_realization0.fits
# 2021-05-31 17:59:52,966 - stpipe - INFO - PSFs will be generated using: /Users/spacegrey/opt/anaconda3/envs/mirage/lib/python3.7/site-packages/mirage/reference_files/mirage_data/nircam/gridded_psf_library/nircam_nrca1_f200w_clear_fovp69_samp5_npsf9_predicted_realization0.fits
# 2021-05-31 17:59:53,040 - mirage.psf.psf_selection.get_psf_wings - INFO - PSF wings will be from: nircam_nrca1_f200w_clear_fovp401_samp1_predicted_realization0.fits
# 2021-05-31 17:59:53,040 - stpipe - INFO - PSF wings will be from: nircam_nrca1_f200w_clear_fovp401_samp1_predicted_realization0.fits
# 2021-05-31 17:59:53,040 - stpipe - INFO - PSF wings will be from: nircam_nrca1_f200w_clear_fovp401_samp1_predicted_realization0.fits
# 2021-05-31 17:59:53,054 - mirage.seed_image.catalog_seed_image - INFO - Creating signal rate image of sidereal synthetic inputs.
# 2021-05-31 17:59:53,054 - stpipe - INFO - Creating signal rate image of sidereal synthetic inputs.
# 2021-05-31 17:59:53,054 - stpipe - INFO - Creating signal rate image of sidereal synthetic inputs.
# 2021-05-31 17:59:53,067 - mirage.seed_image.catalog_seed_image - INFO - Extended list input positions assumed to be in units of RA and Dec.
# 2021-05-31 17:59:53,067 - stpipe - INFO - Extended list input positions assumed to be in units of RA and Dec.
# 2021-05-31 17:59:53,067 - stpipe - INFO - Extended list input positions assumed to be in units of RA and Dec.
# 2021-05-31 17:59:53,077 - mirage.seed_image.catalog_seed_image - WARNING - WARNING: Catalog source_catalog_file.cat does not have a magnitude column called nircam_f200w_magnitude, but does have a generic 'magnitude' column. Continuing simulation using that.
# 2021-05-31 17:59:53,077 - stpipe - WARNING - WARNING: Catalog source_catalog_file.cat does not have a magnitude column called nircam_f200w_magnitude, but does have a generic 'magnitude' column. Continuing simulation using that.
# 2021-05-31 17:59:53,077 - stpipe - WARNING - WARNING: Catalog source_catalog_file.cat does not have a magnitude column called nircam_f200w_magnitude, but does have a generic 'magnitude' column. Continuing simulation using that.
# 2021-05-31 17:59:53,125 - mirage.seed_image.catalog_seed_image - WARNING - No magnitude given for extended source in image2_50au_npix840_nscat1e7ADU.fits.
# 2021-05-31 17:59:53,125 - stpipe - WARNING - No magnitude given for extended source in image2_50au_npix840_nscat1e7ADU.fits.
# 2021-05-31 17:59:53,125 - stpipe - WARNING - No magnitude given for extended source in image2_50au_npix840_nscat1e7ADU.fits.
# 2021-05-31 17:59:53,130 - mirage.seed_image.catalog_seed_image - WARNING - Assuming the original file is in units of counts per sec.
# 2021-05-31 17:59:53,130 - stpipe - WARNING - Assuming the original file is in units of counts per sec.
# 2021-05-31 17:59:53,130 - stpipe - WARNING - Assuming the original file is in units of counts per sec.
# 2021-05-31 17:59:53,137 - mirage.seed_image.catalog_seed_image - WARNING - Multiplying original file values by 'extendedscale'.
# 2021-05-31 17:59:53,137 - stpipe - WARNING - Multiplying original file values by 'extendedscale'.
# 2021-05-31 17:59:53,137 - stpipe - WARNING - Multiplying original file values by 'extendedscale'.
# 2021-05-31 17:59:53,143 - mirage.seed_image.catalog_seed_image - INFO - Number of extended sources found within or close to the requested aperture: 1
# 2021-05-31 17:59:53,143 - stpipe - INFO - Number of extended sources found within or close to the requested aperture: 1
# 2021-05-31 17:59:53,143 - stpipe - INFO - Number of extended sources found within or close to the requested aperture: 1
# 2021-05-31 17:59:53,231 - mirage.seed_image.catalog_seed_image - INFO - Number of extended sources present within the aperture: 1
# 2021-05-31 17:59:53,231 - stpipe - INFO - Number of extended sources present within the aperture: 1
# 2021-05-31 17:59:53,231 - stpipe - INFO - Number of extended sources present within the aperture: 1
# 2021-05-31 17:59:53,236 - mirage.seed_image.catalog_seed_image - INFO - Seed image is 2D.
# 2021-05-31 17:59:53,236 - stpipe - INFO - Seed image is 2D.
# 2021-05-31 17:59:53,236 - stpipe - INFO - Seed image is 2D.
# 2021-05-31 17:59:53,475 - mirage.seed_image.catalog_seed_image - INFO - Extended object image and segmap saved as /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_F200W_CLEAR_extended_seed_image.fits
# 2021-05-31 17:59:53,475 - stpipe - INFO - Extended object image and segmap saved as /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_F200W_CLEAR_extended_seed_image.fits
# 2021-05-31 17:59:53,475 - stpipe - INFO - Extended object image and segmap saved as /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_F200W_CLEAR_extended_seed_image.fits
# 2021-05-31 17:59:53,602 - mirage.seed_image.catalog_seed_image - INFO - Multiplying seed by POM transmission image.
# 2021-05-31 17:59:53,602 - stpipe - INFO - Multiplying seed by POM transmission image.
# 2021-05-31 17:59:53,602 - stpipe - INFO - Multiplying seed by POM transmission image.
# 2021-05-31 17:59:53,608 - mirage.seed_image.catalog_seed_image - INFO - Seed image is 2D.
# 2021-05-31 17:59:53,608 - stpipe - INFO - Seed image is 2D.
# 2021-05-31 17:59:53,608 - stpipe - INFO - Seed image is 2D.
# 2021-05-31 17:59:53,816 - mirage.seed_image.catalog_seed_image - INFO - Final seed image and segmentation map saved as /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_F200W_CLEAR_final_seed_image.fits
# 2021-05-31 17:59:53,816 - stpipe - INFO - Final seed image and segmentation map saved as /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_F200W_CLEAR_final_seed_image.fits
# 2021-05-31 17:59:53,816 - stpipe - INFO - Final seed image and segmentation map saved as /Users/spacegrey/polybox/thesis/simtools/mirage/NIRCAM/image2_sim/jw00005001001_01101_00001_nrca1_uncal_F200W_CLEAR_final_seed_image.fits
# 2021-05-31 17:59:53,818 - mirage.seed_image.catalog_seed_image - INFO - Seed image, segmentation map, and metadata available as:
# 2021-05-31 17:59:53,818 - stpipe - INFO - Seed image, segmentation map, and metadata available as:
# 2021-05-31 17:59:53,818 - stpipe - INFO - Seed image, segmentation map, and metadata available as:
# 2021-05-31 17:59:53,821 - mirage.seed_image.catalog_seed_image - INFO - self.seedimage, self.seed_segmap, self.seedinfo.
#
#
# 2021-05-31 17:59:53,821 - stpipe - INFO - self.seedimage, self.seed_segmap, self.seedinfo.
#
#
# 2021-05-31 17:59:53,821 - stpipe - INFO - self.seedimage, self.seed_segmap, self.seedinfo.

# %%
# test make seed position
filename = cat.params['simSignals']['extended']
extendedscale = 2
lines, pixelflag, magsys = cat.read_point_source_file(filename)
indexes = lines['index']
indexes, lines = cat.remove_outside_fov_sources(indexes, lines, pixelflag, 4096)
mag_column = cat.select_magnitude_column(lines, filename)
for indexnum, values in zip(indexes, lines):
    pixelx, pixely, ra, dec, ra_str, dec_str = cat.get_positions(values['x_or_RA'],
                                                                values['y_or_Dec'],
                                                                pixelflag, 4096)
    mag = None
    ext_stamp = fits.getdata(values['filename'])
    eshape = np.array(ext_stamp.shape)
    edgey, edgex = eshape // 2
    miny = 0
    maxy = cat.subarray_bounds[3] - cat.subarray_bounds[1]
    minx = 0
    maxx = cat.subarray_bounds[2] - cat.subarray_bounds[0]
    miny -= edgey
    maxy += edgey
    minx -= edgex
    maxx += edgex
    norm_factor = np.sum(ext_stamp)
    countrate = norm_factor * extendedscale
    if pixely > miny and pixely < maxy and pixelx > minx and pixelx < maxx:
        entry = [indexnum, pixelx, pixely, ra_str, dec_str, ra, dec, mag]
# Out:
# 2021-05-31 18:00:09,019 - mirage.seed_image.catalog_seed_image - WARNING - WARNING: Catalog source_catalog_file.cat does not have a magnitude column called nircam_f200w_magnitude, but does have a generic 'magnitude' column. Continuing simulation using that.
# 2021-05-31 18:00:09,019 - stpipe - WARNING - WARNING: Catalog source_catalog_file.cat does not have a magnitude column called nircam_f200w_magnitude, but does have a generic 'magnitude' column. Continuing simulation using that.
# 2021-05-31 18:00:09,019 - stpipe - WARNING - WARNING: Catalog source_catalog_file.cat does not have a magnitude column called nircam_f200w_magnitude, but does have a generic 'magnitude' column. Continuing simulation using that.

# %%
pixelx, pixely, ra, dec, ra_str, dec_str, minx, maxx, miny, maxy
# Out:
# (1035.2140797253817,
#  977.9647843760524,
#  47.554,
#  -10.1,
#  '03:10:12.9600',
#  '-10:05:60.0000',
#  -420,
#  2467,
#  -420,
#  2467)

# %%
cat.coord_transform
# Out:
# <CompoundModel(offset_0=1., offset_1=1., offset_2=-1024.5, offset_3=-1024.5, c0_0_5=-0., c1_0_5=0.03113927, c2_0_5=0., c3_0_5=0., c4_0_5=-0., c5_0_5=0., c0_1_5=0., c0_2_5=-0.00000003, c0_3_5=0., c0_4_5=-0., c0_5_5=-0., c1_1_5=-0.00000021, c1_2_5=0., c1_3_5=-0., c1_4_5=0., c2_1_5=0., c2_2_5=-0., c2_3_5=0., c3_1_5=-0., c3_2_5=0., c4_1_5=0., c0_0_6=0., c1_0_6=0.00002575, c2_0_6=0.00000007, c3_0_6=0., c4_0_6=-0., c5_0_6=0., c0_1_6=0.03132232, c0_2_6=-0.00000014, c0_3_6=0., c0_4_6=-0., c0_5_6=0., c1_1_6=0.00000004, c1_2_6=0., c1_3_6=-0., c1_4_6=0., c2_1_6=0., c2_2_6=-0., c2_3_6=0., c3_1_6=-0., c3_2_6=0., c4_1_6=0., c0_0_8=0., c1_0_8=-0.99995176, c0_1_8=-0.00982238, c0_0_9=0., c1_0_9=-0.00982238, c0_1_9=0.99995176, offset_10=120.525464, offset_11=-527.543132)>

# %%
import pysiaf
loc_v2, loc_v3 = pysiaf.utils.rotations.getv2v3(cat.attitude_matrix, 47.55, -10.1)
pixelx, pixely = cat.coord_transform.inverse(loc_v2, loc_v3)
pixelx, pixely
# Out:
# (1490.2794964091681, 981.6426584758801)
